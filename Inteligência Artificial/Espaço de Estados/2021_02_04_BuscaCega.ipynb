# %% [markdown]
# **Instituto de Informática - UFG**
#
# Disciplina: Inteligência Artificial
#
# Prof. Cedric Luiz de Carvalho
#
# Aluna(o):
#
#
#
# ---

# %% [markdown]
#  Resolução de problemas por meio de busca
# ## Buscas não informadas (cegas)
#
# - **Busca em largura**: A raiz é expandida; todos os nós gerados pela expansão da raiz são expandidos; os sucessores dos nós gerados pela expansão da raiz são expandidos; o processo se repete até que a meta seja atingida.
# - **Busca de custo uniforme**: a busca em Largura pode ser modificada, expandindo-se sempre o nó de menor custo da fronteira ao invés nó de menor profundidade.
# - **Busca em profundidade**: expande sempre um dos nós de maior profundidade na árvore. Quando a busca encontra um nó que não pode ser expandido, retorna e expande os nós que estão pendentes.
# - **Busca em profundidade limitada**: a busca em profundidade é modificada, impondo-se um limite máximo na profundidade.
# - **Busca em aprofundamento iterativo**: é feita uma busca em profundidade limitada, incrementando-se sucessivamente o limite máximo da busca.

# %% [markdown]
# **Modelo:**
#
#    * Descrição matemática abstrata
#    * Representação abstrada do mundo (contexto do problema)

# %% [markdown]
# **Um problema:**
#
#
#
# *   Estado inicial
# *   Ações possíveis
# *   Modelo de transição (determinação dos sucessores)
# *   Teste da meta
# *   Função de custo do caminho

# %% [markdown]
# **Abstração:**
#
#       * Desconsiderar o que não seja relevante para o problema do mundo real

# %% [markdown]
# **Algoritmos de Busca (Ben Coppin)**:

# %%
Function depth ()
{
    queue = []; // initialize an empty queue
    state = root_node; // initialize the start state
    while (true)
      {
        if is_goal (state)
          then return SUCCESS
        else add_to_front_of_queue (successors (state));
        if queue == []
          then report FAILURE;
        state = queue [0]; // state = first item in queue
        remove_first_item_from (queue);
      }
}

# %%
Function recursive_depth (state)
{
  if is_goal (state)
    then return SUCCESS
  else
  {
    remove_from_stack (state);
    add_to_stack (successors (state))
  }
  while (stack != [])
  {
    if recursive_depth (stack [0]) == SUCCESS
      then return SUCCESS;
    remove_first_item_from (stack);
  }
  return FAILURE;
}

# %%
Function breadth ()
{
  queue = []; // initialize an empty queue
  state = root_node; // initialize the start state
  while (true)
  {
    if is_goal (state)
        then return SUCCESS
    else add_to_back_of_queue (successors (state));
    if queue == []
       then report FAILURE;
    state = queue [0]; // state = first item in queue
    remove_first_item_from (queue);
  }
}

# %% [markdown]
# ## Exemplos de problemas (Russel & Norvig)

# %% [markdown]
# ### Problema de roteamento
#
# *   Considere que um turista esteja viajando para a Romênia. Ao chegar lá, deseja se deslocar de uma cidade a outra pelo melhor trajeto possível. O turista tem a sua disposição o mapa dado a seguir que mostra as conexões entre as cidades e a distância entre elas.

# %% [markdown]
# <img src="https://cse-robotics.engr.tamu.edu/dshell/cs625/images/map.jpg" height="366" width="603">

# %% [markdown]
# * O espaço de estados pode ser representado por um grafo, onde os vértices são os estados do problema (as cidades, neste caso) e as arestas são as ações (neste caso, dirigir pelas estradas).
#
# * Representaremos as cidades pela letra inicial do seu nome. O grafo será representado por uma estrutura **dict** que mapeia cada cidade e seus vizinhos diretos (aqueles ligados diretamente à cidade por uma estrada).

# %%
romênia = {
 'A': ['Z', 'T', 'S'],
 'B': ['F', 'P', 'G', 'U'],
 'C': ['D', 'R', 'P'],
 'D': ['M', 'C'],
 'E': ['H'],
 'F': ['S', 'B'],
 'G': ['B'],
 'H': ['U', 'E'],
 'I': ['N', 'V'],
 'L': ['T', 'M'],
 'M': ['L', 'D'],
 'N': ['I'],
 'O': ['Z', 'S'],
 'P': ['R', 'C', 'B'],
 'R': ['S', 'C', 'P'],
 'S': ['A', 'O', 'F', 'R'],
 'T': ['A', 'L'],
 'U': ['B', 'V', 'H'],
 'V': ['U', 'I'],
 'Z': ['O', 'A']}

# %% [markdown]
# * Se o turista desejar se deslocar de A para B, deverá considerar os possíveis caminhos a partir de A:

# %%
romênia['A']
# Out:
# ['Z', 'T', 'S']

# %%
import networkx as nx

graph = nx.Graph()

for node in romênia:
  for neighbor in romênia[node]:
    graph.add_edge(node, neighbor)

nx.draw(graph, with_labels=True, node_color='lightgreen')

# %% [markdown]
#  **Qual escolher?**
#
# * Um dos nós da **fronteira**

# %% [markdown]
# ### Busca em largura

# %%
from collections import deque # Doubly-ended queue: pop from left, append to right.

def breadth_first(start, goal, neighbors):
    "Find a shortest sequence of states from start to the goal."
    frontier = deque([start]) # A queue of states
    previous = {start: None}  # start has no previous state; other states will
    while frontier:
        s = frontier.popleft()
        if s == goal:
            return path(previous, s)
        for s2 in neighbors[s]:
            if s2 not in previous:
                frontier.append(s2)
                previous[s2] = s
                
def path(previous, s): 
    "Return a list of states that lead to state s, according to the previous dict."
    return [] if (s is None) else path(previous, previous[s]) + [s]

# %% [markdown]
# * **Exemplos:**

# %%
breadth_first('A', 'B', romênia)

# %%
breadth_first('L', 'N', romênia)

# %%
breadth_first('N', 'L', romênia)

# %%
breadth_first('E', 'E', romênia)

# %% [markdown]
# ### Problema da escada de palavras
#
# * Dada uma palavra, transformá-la em uma outra trocando apenas uma letra a cada passo. Por exemplo, para transformar
# **'dizes' ** em **'chapa'** precisamos de **11** passos:
#
# 'dizes' ->  'dites' ->  'dates' ->  'danes' ->  'danos' ->  'canos' ->  'canoa' ->  'canta' ->
#  'cauta' ->  'chuta' ->  'chupa' ->  'chapa'
#
#
# Podemos obter uma lista das palavras de 5 letras da Língua Portuguesa. Por exemplo, através do portal: https://www.palavras.net/
#
#
#  * Antes de iniciar os testes, carregar os arquivos python a seguir para a máquina virtual: util.py e search.py

# %%
from google.colab import files # carregar os arquivos  'utils.py e search.py mapa-brasil-estados-capitais.jpg'
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8761467c-dfaa-47a3-a02a-0cbb0f8f14ac" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8761467c-dfaa-47a3-a02a-0cbb0f8f14ac">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving search.py to search (1).py
# Saving utils.py to utils (1).py

# %%
from google.colab import files # carregar o arquivo  'palavras.txt'
uploaded = files.upload()
# Out:
#      <input type="file" id="files-782a15e3-a59a-4b98-b03f-afcf166cd50a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-782a15e3-a59a-4b98-b03f-afcf166cd50a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving palavras.txt to palavras.txt

# %%
# !ls    # checar se o arquivo foi devidamente carregado
# Out:
#  aima-data      __pycache__  'search (1).py'  'utils (1).py'
#  palavras.txt   sample_data   search.py        utils.py

# %%
# !mkdir aima-data/

# %%
# !mv palavras.txt aima-data/

# %%
# !ls aima-data/
# Out:
# palavras.txt

# %%
from search import *
sgb_words = open_data("palavras.txt") #https://www.palavras.net/

# %% [markdown]
# * Podemos associar as palavras neste aquivo à variável PALAVRAS:

# %%
PALAVRAS = set(sgb_words.read().split())
len(PALAVRAS)
# Out:
# 2000

# %% [markdown]
# * Podemos definir uma função que retorna as palavras que diferem apenas uma letra da palavra dada:

# %%
def vizinhas(word):
    "All words that are one letter away from this word."
    pal_vizinhas = {word[:i] + c + word[i+1:]
                 for i in range(len(word))
                 for c in 'abcdefghijklmnopqrstuvwxyz'
                 if c != word[i]}
    return pal_vizinhas & PALAVRAS

# %% [markdown]
# * Exemplos:

# %%
vizinhas('dizes')
# Out:
# {'dites', 'dizei', 'dizem', 'dizer'}

# %%
vizinhas('eriço')
# Out:
# {'erijo', 'eriça'}

# %%
vizinhas('átrio')
# Out:
# set()

# %% [markdown]
# * Agora, podemos criar um dicionário para acomodar as vizinhas: {palavra: {vizinha, ...}}:

# %%
palavras_vizinhas = {word: vizinhas(word)
                  for word in PALAVRAS}

# %%
palavras_vizinhas
# Out:
# {'citai': {'catai', 'citam', 'citar', 'citas', 'citei', 'cotai', 'ditai'},
#  'Amapá': set(),
#  'calam': {'balam',
#   'cagam',
#   'caiam',
#   'calai',
#   'calar',
#   'calas',
#   'calem',
#   'capam',
#   'casam',
#   'catam',
#   'cavam',
#   'colam'},
#  'chora': {'choca', 'chore', 'choro', 'chova'},
#  'ávido': {'ácido', 'árido', 'ávida'},
#  'aonde': {'bonde', 'conde', 'donde'},
#  'eriço': {'erijo', 'eriça'},
#  'civil': {'civis'},
#  'bonde': {'aonde', 'borde', 'bunde', 'conde', 'donde'},
#  'basto': {'basta', 'baste', 'busto', 'casto'},
#  'acues': {'aches', 'acuas', 'acuei', 'acuem', 'agues', 'atues'},
#  'coevo': {'coemo', 'coeso', 'coeva', 'corvo'},
#  'aldeã': set(),
#  'átrio': set(),
#  'balsa': {'balia', 'bolsa'},
#  'cisma': {'cisca', 'cisme', 'cismo'},
#  'douta': {'doura', 'douto'},
#  'calha': {'calca', 'calda', 'calhe', 'calho', 'calma', 'calva', 'colha'},
#  'cação': {'carão'},
#  'droga': {'draga', 'drogo'},
#  'beije': {'beija', 'beijo', 'beire'},
#  'dorme': {'dormi'},
#  'ergui': {'ergue'},
#  'andou': {'andor'},
#  'capaz': {'capai', 'capam', 'capar', 'capas', 'capuz'},
#  'Érica': {'Érico'},
#  'acudo': {'acuda', 'acudi', 'acuso', 'agudo', 'ajudo', 'aludo'},
#  'amemo': {'amamo', 'ameno', 'amimo', 'aremo', 'atemo'},
#  'chiam': {'caiam', 'ceiam', 'chiai', 'chiar', 'chias', 'chiem', 'criam'},
#  'bunda': {'banda', 'bunde', 'bundo'},
#  'camas': {'cacas',
#   'cagas',
#   'caias',
#   'calas',
#   'canas',
#   'capas',
#   'caras',
#   'casas',
#   'catas',
#   'cavas',
#   'comas',
#   'damas'},
#  'atuam': {'acuam',
#   'aguam',
#   'anuam',
#   'atuai',
#   'atual',
#   'atuar',
#   'atuas',
#   'atuem'},
#  'assar': {'assai', 'assam', 'assas', 'assaz'},
#  'entoá': {'enjoá', 'entoa', 'entoe', 'entrá'},
#  'ativa': {'atava', 'atina', 'atira', 'ative', 'ativo', 'aviva'},
#  'aditá': {'adirá',
#   'adita',
#   'adite',
#   'adito',
#   'adotá',
#   'agitá',
#   'apitá',
#   'editá'},
#  'anuís': {'anuas', 'anuis', 'anuía'},
#  'alijá': {'alija', 'alije', 'alijo', 'alisá', 'alojá'},
#  'bufas': {'bufai', 'bufam', 'bufar', 'bufes', 'bulas'},
#  'curve': {'curse', 'curte', 'curva', 'curvo'},
#  'berre': {'barre', 'beire', 'berra', 'berro', 'borre', 'cerre'},
#  'bobos': {'bobas', 'bolos'},
#  'ajuda': {'acuda', 'aguda', 'ajude', 'ajudo', 'aluda'},
#  'cabos': {'cabes', 'cacos', 'calos', 'canos', 'caros', 'casos', 'cubos'},
#  'coçou': {'caçou', 'colou', 'corou', 'cotou'},
#  'arejá': {'areja', 'areje', 'arejo'},
#  'babei': {'babai', 'babem', 'babes', 'batei', 'bebei', 'cabei'},
#  'bufai': {'bufam', 'bufar', 'bufas', 'bufei'},
#  'disse': {'desse', 'disso', 'diste'},
#  'aviem': {'adiem', 'afiem', 'aliem', 'aviam', 'aviei', 'avier', 'avies'},
#  'arroz': set(),
#  'cólon': set(),
#  'aremo': {'amemo', 'aramo', 'arejo', 'atemo', 'cremo'},
#  'crive': {'crave', 'crime', 'crise', 'criva', 'crivo'},
#  'choco': {'checo', 'choca', 'choro', 'chovo'},
#  'coroa': {'corda', 'corja', 'coroe', 'coros', 'corou', 'corra', 'corta'},
#  'devem': {'derem', 'devam', 'devei', 'dever', 'deves', 'deveu'},
#  'bebei': {'babei', 'bebem', 'beber', 'bebes', 'bebeu'},
#  'divas': {'davas', 'devas', 'dicas', 'digas', 'ditas'},
#  'escôo': set(),
#  'enfia': {'enfie', 'enfim', 'enfio', 'envia'},
#  'curvá': {'cursá', 'curva', 'curve', 'curvo'},
#  'borrá': {'barrá', 'berrá', 'bordá', 'borra', 'borre', 'borro'},
#  'coaxo': {'coado', 'coajo', 'coamo', 'coaxa', 'coaxe'},
#  'demão': {'dedão'},
#  'beirá': {'beijá', 'beira', 'beire', 'beiro', 'berrá'},
#  'asses': {'assas', 'assei', 'assem', 'assis', 'esses'},
#  'corda': {'borda', 'cerda', 'coada', 'corja', 'coroa', 'corra', 'corta'},
#  'drogá': {'dragá', 'droga', 'drogo'},
#  'cocal': {'bocal', 'coral'},
#  'babão': {'baião', 'balão', 'barão'},
#  'depôs': {'depus'},
#  'babar': {'babai', 'babam', 'babas', 'bazar'},
#  'danam': {'danai', 'danar', 'danas', 'danem', 'datam', 'davam'},
#  'afane': {'abane', 'afana', 'afano', 'afine'},
#  'aérea': {'aéreo'},
#  'caiam': {'cagam',
#   'caiai',
#   'caiar',
#   'caias',
#   'caiem',
#   'calam',
#   'capam',
#   'casam',
#   'catam',
#   'cavam',
#   'ceiam',
#   'chiam',
#   'criam'},
#  'corvo': {'cervo', 'coevo', 'corno', 'corpo', 'corro', 'corto', 'curvo'},
#  'davam': {'cavam', 'danam', 'datam', 'davas', 'devam'},
#  'alugá': {'alagá', 'alegá', 'aluga', 'alugo'},
#  'ativo': {'atido', 'atino', 'atiro', 'ativa', 'ative', 'avivo'},
#  'aguam': {'acuam',
#   'agiam',
#   'aguai',
#   'aguar',
#   'aguas',
#   'aguem',
#   'anuam',
#   'atuam'},
#  'benta': {'beata', 'benza', 'besta'},
#  'conde': {'aonde', 'bonde', 'cinde', 'conte', 'donde'},
#  'cante': {'canse', 'canta', 'canto', 'capte', 'conte', 'dante'},
#  'atear': {'apear', 'ateai', 'atuar'},
#  'breca': {'breco', 'broca'},
#  'anglo': {'anelo', 'anulo'},
#  'dobra': {'cobra', 'doara', 'dobre', 'dobro', 'doera', 'doura'},
#  'cisca': {'casca', 'cisco', 'cisma', 'disca'},
#  'belos': {'becos', 'belas', 'bolos'},
#  'atraí': {'atrai'},
#  'claro': {'clamo', 'clara', 'clero', 'cloro'},
#  'atire': {'atice', 'atine', 'atira', 'atiro', 'ative', 'ature'},
#  'abuse': {'abusa', 'abuso', 'acuse'},
#  'boiei': {'boiai', 'bolei', 'botei'},
#  'balão': {'babão', 'baião', 'barão', 'bolão'},
#  'abalá': {'abafá', 'abala', 'abale', 'abalo', 'abaná'},
#  'abreu': {'abrem', 'abres', 'abriu'},
#  'azula': {'adula', 'anula', 'azule', 'azulo'},
#  'bauru': set(),
#  'baque': {'beque', 'bique'},
#  'adiro': {'adido', 'adimo', 'adira', 'adito', 'adoro', 'afiro', 'atiro'},
#  'boato': {'beato', 'boate'},
#  'ceder': {'cedei', 'cedem', 'cedes', 'cedeu'},
#  'antes': {'andes', 'antas', 'artes', 'entes'},
#  'aflui': {'ablui', 'aflua', 'afluo'},
#  'bicho': {'bicha', 'bucho'},
#  'babai': {'babam', 'babar', 'babas', 'babei'},
#  'durma': {'durmo'},
#  'doava': {'coava', 'doada', 'doara'},
#  'amado': {'alado', 'amada', 'amamo', 'amaro', 'amido', 'arado', 'atado'},
#  'adega': {'adaga', 'alega', 'apega'},
#  'amara': {'amada',
#   'amaro',
#   'amava',
#   'apara',
#   'arara',
#   'atara',
#   'avara',
#   'azara'},
#  'ábaco': set(),
#  'cubra': {'cabra', 'cobra', 'cubro'},
#  'caldo': {'caido', 'calco', 'calda', 'calho', 'calmo', 'calvo', 'cardo'},
#  'andam': {'andai', 'andar', 'andas', 'andem', 'anuam', 'ardam'},
#  'cegar': {'cagar', 'cegai', 'cegam', 'cegas'},
#  'anule': {'adule', 'anele', 'anula', 'anulo', 'azule'},
#  'Babel': set(),
#  'artes': {'antes', 'ardes', 'arfes', 'armes'},
#  'drogo': {'drago', 'droga'},
#  'blefa': {'blefe', 'blefo'},
#  'dilua': {'dilui', 'diluo'},
#  'abras': {'abram', 'abres', 'abris', 'auras'},
#  'anciã': set(),
#  'culpá': {'culpa', 'culpe', 'culpo'},
#  'damas': {'camas',
#   'dadas',
#   'damos',
#   'danas',
#   'datas',
#   'davas',
#   'domas',
#   'dumas'},
#  'azuis': {'anuis'},
#  'caída': {'calda', 'cauda', 'caído', 'caíra'},
#  'elejo': {'eleja', 'elevo'},
#  'baixe': {'baile', 'baixa', 'baixo'},
#  'cravá': {'crava', 'crave', 'cravo', 'crivá'},
#  'Emaús': set(),
#  'duplo': {'dublo', 'duelo', 'dupla'},
#  'atolá': {'acolá', 'amolá', 'atola', 'atole', 'atolo'},
#  'citou': {'catou', 'cotou', 'ditou'},
#  'baile': {'baila', 'bailo', 'baixe'},
#  'anuir': {'anuis', 'anuiu'},
#  'alvor': {'alvos'},
#  'assim': {'assam', 'assem', 'assis'},
#  'cospe': set(),
#  'alvas': {'algas', 'alias', 'almas', 'altas', 'alves', 'alvos'},
#  'docas': {'bocas', 'dicas', 'domas', 'donas', 'dopas', 'dosas', 'dotas'},
#  'colas': {'bolas',
#   'calas',
#   'celas',
#   'colai',
#   'colam',
#   'colar',
#   'coles',
#   'comas',
#   'copas',
#   'coras',
#   'cosas',
#   'cotas',
#   'covas',
#   'coxas',
#   'cozas'},
#  'canja': {'canga', 'canoa', 'cansa', 'canta', 'cinja'},
#  'arcas': {'ancas',
#   'arcai',
#   'arcam',
#   'arcar',
#   'arcos',
#   'ardas',
#   'arfas',
#   'armas'},
#  'bicai': {'bicam', 'bicar', 'bicas'},
#  'abram': {'abras', 'abrem'},
#  'Elixa': {'Elisa'},
#  'barro': {'barco',
#   'bardo',
#   'barra',
#   'barre',
#   'berro',
#   'borro',
#   'burro',
#   'carro'},
#  'erice': {'erige'},
#  'cinza': {'cinda', 'cinja', 'cinta'},
#  'arfas': {'arcas', 'ardas', 'arfai', 'arfam', 'arfar', 'arfes', 'armas'},
#  'bingo': set(),
#  'afogo': {'afago', 'afobo', 'afofo', 'afoga', 'aforo'},
#  'dosar': {'domar', 'dopar', 'dosai', 'dosam', 'dosas', 'dotar'},
#  'calma': {'calca', 'calda', 'calha', 'calmo', 'calva'},
#  'bulam': {'balam', 'bolam', 'bufam', 'bulas'},
#  'asila': {'asile', 'asilo', 'axila'},
#  'dedal': set(),
#  'éguas': {'aguas'},
#  'arava': {'amava', 'arada', 'arara', 'atava', 'brava', 'crava'},
#  'ature': {'apure', 'atire', 'atura', 'aturo'},
#  'curou': {'corou', 'durou'},
#  'cacho': {'cacto', 'calho', 'cocho'},
#  'ceemo': {'ceamo', 'coemo', 'cremo'},
#  'douro': {'couro', 'dobro', 'doura', 'doure', 'douto'},
#  'curto': {'certo',
#   'corto',
#   'culto',
#   'curso',
#   'curta',
#   'curte',
#   'curti',
#   'curvo',
#   'custo'},
#  'armes': {'ardes', 'arfes', 'armas', 'armei', 'armem', 'artes'},
#  'Ceará': set(),
#  'adoto': {'adito', 'adoro', 'adota', 'adote', 'anoto', 'azoto'},
#  'durmo': {'dermo', 'durma'},
#  'autue': {'autua', 'autuo'},
#  'atlas': {'atuas', 'aulas'},
#  'aluno': {'aludo', 'alugo', 'aluna'},
#  'afaga': {'adaga', 'afago', 'afana', 'afoga', 'alaga', 'apaga'},
#  'anela': {'anele', 'anelo', 'anexa', 'anula', 'apela'},
#  'burro': {'barro', 'berro', 'borro', 'burgo', 'burlo', 'burra'},
#  'abane': {'abade', 'abafe', 'abale', 'abana', 'abano', 'abate', 'afane'},
#  'deitá': {'deita', 'deite', 'deito', 'deixá'},
#  'cacto': {'cacho', 'canto', 'capto', 'casto', 'cauto'},
#  'ameis': {'amais', 'ameia', 'areis', 'ateis'},
#  'altas': {'aftas',
#   'algas',
#   'alias',
#   'almas',
#   'altar',
#   'altos',
#   'alvas',
#   'antas',
#   'aptas'},
#  'botai': {'boiai',
#   'bolai',
#   'botam',
#   'botar',
#   'botas',
#   'botei',
#   'cotai',
#   'dotai'},
#  'agirá': {'adirá', 'agira', 'agitá', 'atirá', 'avirá'},
#  'cucas': {'cacas', 'cubas', 'cucos', 'cuias', 'cujas', 'curas'},
#  'dares': {'bares',
#   'danes',
#   'darei',
#   'darem',
#   'dates',
#   'deres',
#   'dores',
#   'dures'},
#  'avias': {'adias',
#   'afias',
#   'agias',
#   'alias',
#   'aviai',
#   'aviam',
#   'aviar',
#   'avies',
#   'azias'},
#  'botem': {'batem', 'bolem', 'botam', 'botei', 'botes', 'cotem', 'dotem'},
#  'armam': {'arcam', 'ardam', 'arfam', 'armai', 'armar', 'armas', 'armem'},
#  'cotes': {'botes',
#   'cates',
#   'cites',
#   'coces',
#   'coles',
#   'comes',
#   'cones',
#   'cores',
#   'coses',
#   'cotas',
#   'cotei',
#   'cotem',
#   'cozes',
#   'dotes'},
#  'areis': {'ameis', 'arais', 'ardis', 'areia', 'ateis'},
#  'dobro': {'cobro', 'dobra', 'dobre', 'douro'},
#  'aguça': {'aguda', 'aguço'},
#  'chovo': {'choco', 'choro', 'chova', 'chove', 'chovi'},
#  'águas': {'aguas'},
#  'dardo': {'bardo', 'cardo', 'dando'},
#  'coroe': {'coroa', 'coros', 'corou', 'corre', 'corte'},
#  'alaga': {'adaga', 'afaga', 'alada', 'alago', 'alega', 'aluga', 'apaga'},
#  'assaz': {'assai', 'assam', 'assar', 'assas'},
#  'dista': {'desta', 'dieta', 'disca', 'diste', 'disto'},
#  'duque': {'dique'},
#  'calho': {'cacho',
#   'calco',
#   'caldo',
#   'calha',
#   'calhe',
#   'calmo',
#   'calvo',
#   'colho'},
#  'canal': {'banal', 'canas', 'casal'},
#  'botão': {'bolão'},
#  'avaro': {'amaro', 'aparo', 'avara', 'azaro'},
#  'atues': {'acues', 'agues', 'atuas', 'atuei', 'atuem', 'atuns'},
#  'Chico': {'Chica'},
#  'ajudá': {'ajuda', 'ajude', 'ajudo'},
#  'duela': {'dubla', 'duele', 'duelo', 'dupla'},
#  'descê': {'desce', 'desci'},
#  'datem': {'batem',
#   'catem',
#   'danem',
#   'darem',
#   'datam',
#   'datei',
#   'dates',
#   'ditem',
#   'dotem'},
#  'congá': {'contá'},
#  'aguce': set(),
#  'bocas': {'becas',
#   'bicas',
#   'bobas',
#   'bocal',
#   'bodas',
#   'bolas',
#   'botas',
#   'docas'},
#  'dormi': {'dorme'},
#  'adoçá': {'adorá', 'adotá', 'adoça', 'adoço'},
#  'cenas': {'canas', 'cedas', 'cegas', 'ceias', 'celas', 'ceras'},
#  'brios': {'brins'},
#  'avivo': {'ativo', 'avimo', 'aviso', 'aviva', 'avive'},
#  'acabe': {'acaba', 'acabo', 'acate'},
#  'coroá': {'coroa', 'coroe', 'coros', 'corou', 'cortá'},
#  'caçai': {'cagai',
#   'caiai',
#   'calai',
#   'capai',
#   'casai',
#   'catai',
#   'cavai',
#   'caçam',
#   'caçar',
#   'caças',
#   'coçai'},
#  'apeno': {'aceno', 'ameno', 'apego', 'apeio', 'apelo', 'apena', 'apene'},
#  'corra': {'borra',
#   'cerra',
#   'coara',
#   'cobra',
#   'corda',
#   'corja',
#   'coroa',
#   'corre',
#   'corri',
#   'corro',
#   'corta'},
#  'cagam': {'cagai',
#   'cagar',
#   'cagas',
#   'caiam',
#   'calam',
#   'capam',
#   'casam',
#   'catam',
#   'cavam',
#   'cegam'},
#  'capes': {'cabes',
#   'caces',
#   'caies',
#   'cales',
#   'capas',
#   'capei',
#   'capem',
#   'cases',
#   'cates',
#   'caves'},
#  'achei': {'achai', 'achem', 'aches', 'acuei'},
#  'coxas': {'colas',
#   'comas',
#   'copas',
#   'coras',
#   'cosas',
#   'cotas',
#   'covas',
#   'coxos',
#   'cozas'},
#  'Argos': set(),
#  'célia': set(),
#  'casso': {'canso', 'casco', 'cassa', 'casse', 'casto', 'causo', 'cesso'},
#  'boate': {'boato'},
#  'datam': {'batam',
#   'catam',
#   'danam',
#   'datai',
#   'datar',
#   'datas',
#   'datem',
#   'davam',
#   'ditam',
#   'dotam'},
#  'caias': {'baias',
#   'cacas',
#   'cagas',
#   'caiai',
#   'caiam',
#   'caiar',
#   'caies',
#   'calas',
#   'camas',
#   'canas',
#   'capas',
#   'caras',
#   'casas',
#   'catas',
#   'cavas',
#   'ceias',
#   'chias',
#   'crias',
#   'cuias'},
#  'bardo': {'bando', 'barco', 'barro', 'bordo', 'cardo', 'dardo'},
#  'atino': {'afino', 'atido', 'atina', 'atine', 'atiro', 'ativo'},
#  'desça': {'dessa', 'desta', 'desço'},
#  'afoga': {'afaga', 'afoba', 'afofa', 'afogo', 'afora'},
#  'balde': set(),
#  'cagar': {'cagai',
#   'cagam',
#   'cagas',
#   'caiar',
#   'calar',
#   'capar',
#   'casar',
#   'catar',
#   'cavar',
#   'cegar'},
#  'casos': {'cabos',
#   'cacos',
#   'calos',
#   'canos',
#   'caros',
#   'casas',
#   'cases',
#   'casou'},
#  'alojá': {'alijá', 'alocá', 'aloja', 'aloje', 'alojo'},
#  'César': set(),
#  'ateai': {'apeai', 'atear', 'ateei', 'atrai', 'atuai'},
#  'dopas': {'copas',
#   'docas',
#   'domas',
#   'donas',
#   'dopai',
#   'dopam',
#   'dopar',
#   'dopes',
#   'dosas',
#   'dotas'},
#  'calou': {'cagou',
#   'caiou',
#   'calor',
#   'calos',
#   'capou',
#   'casou',
#   'catou',
#   'cavou',
#   'colou'},
#  'copio': {'copia', 'copie'},
#  'ceiem': {'caiem', 'cedem', 'ceiam', 'ceies', 'chiem', 'criem'},
#  'arfam': {'arcam', 'ardam', 'arfai', 'arfar', 'arfas', 'arfem', 'armam'},
#  'afeto': {'abeto', 'aceto', 'afeta', 'afete'},
#  'dores': {'cores',
#   'dares',
#   'deres',
#   'domes',
#   'dopes',
#   'doses',
#   'dotes',
#   'dures'},
#  'curse': {'cursa', 'curso', 'curte', 'curve'},
#  'cabra': {'cabia', 'cobra', 'cubra'},
#  'Átila': {'Ávila'},
#  'Abner': set(),
#  'atrai': {'ateai', 'atuai'},
#  'doais': {'coais', 'doeis', 'duais'},
#  'canse': {'cansa', 'canso', 'cante', 'casse', 'cause'},
#  'armar': {'arcar', 'arfar', 'armai', 'armam', 'armas'},
#  'elmos': {'ermos'},
#  'amará': {'amara', 'amaro', 'apará', 'arará', 'atará', 'azará'},
#  'cedeu': {'cedei', 'cedem', 'ceder', 'cedes'},
#  'chama': {'chaga', 'chame', 'chamo', 'chapa', 'chata', 'clama'},
#  'ceras': {'caras',
#   'cedas',
#   'cegas',
#   'ceias',
#   'celas',
#   'cenas',
#   'coras',
#   'curas',
#   'deras'},
#  'balam': {'babam', 'balas', 'balem', 'batam', 'bolam', 'bulam', 'calam'},
#  'acuso': {'abuso', 'acaso', 'aceso', 'acudo', 'acusa', 'acuse'},
#  'borde': {'bonde', 'borda', 'bordo', 'borre'},
#  'crido': {'caido', 'credo', 'crivo', 'cuido'},
#  'beiço': {'beijo', 'beiro', 'berço'},
#  'bufão': {'bujão'},
#  'chupe': {'chupa', 'chupo', 'chute'},
#  'aliso': {'alijo', 'alisa', 'alise', 'aviso'},
#  'assoa': {'assoe', 'assou'},
#  'agite': {'adite', 'agita', 'agito', 'apite'},
#  'cedam': {'cedas', 'cedem', 'cegam', 'ceiam'},
#  'dures': {'cures',
#   'dares',
#   'deres',
#   'dores',
#   'duras',
#   'durei',
#   'durem',
#   'duros'},
#  'denso': {'censo', 'densa'},
#  'envia': {'enfia', 'envie', 'envio'},
#  'ejetá': {'ejeta', 'ejete', 'ejeto'},
#  'coeis': {'ceeis', 'coais', 'doeis'},
#  'brecá': {'breca', 'breco', 'brocá'},
#  'caiei': {'cabei',
#   'cacei',
#   'caiai',
#   'caiem',
#   'caies',
#   'calei',
#   'capei',
#   'casei',
#   'catei',
#   'cavei',
#   'chiei',
#   'criei'},
#  'bemol': set(),
#  'capai': {'cagai',
#   'caiai',
#   'calai',
#   'capam',
#   'capar',
#   'capas',
#   'capaz',
#   'capei',
#   'casai',
#   'catai',
#   'cavai'},
#  'carta': {'canta',
#   'capta',
#   'carga',
#   'carpa',
#   'casta',
#   'cauta',
#   'certa',
#   'corta',
#   'curta'},
#  'bulir': {'balir', 'bulia', 'bulis', 'buliu'},
#  'calco': {'calca', 'calce', 'caldo', 'calho', 'calmo', 'calvo', 'casco'},
#  'arder': {'ardei', 'ardem', 'ardes', 'ardeu', 'ardor'},
#  'culpo': {'culpa', 'culpe', 'culto', 'cuspo'},
#  'criou': {'caiou', 'chiou'},
#  'aviai': {'adiai', 'afiai', 'aliai', 'aviam', 'aviar', 'avias', 'aviei'},
#  'errai': {'erram', 'errar', 'erras', 'errei'},
#  'alcem': {'alcei', 'alces', 'aliem'},
#  'credo': {'crede', 'creio', 'cremo', 'crido'},
#  'coeva': {'coava', 'coesa', 'coevo'},
#  'amimá': {'amigá', 'amima', 'amime', 'amimo', 'animá'},
#  'ápice': set(),
#  'barco': {'banco', 'barca', 'bardo', 'barro'},
#  'cuspi': {'cuspa', 'cuspo'},
#  'bolha': {'bocha', 'bolsa', 'colha'},
#  'acuou': {'achou', 'aguou', 'atuou'},
#  'couve': {'coube'},
#  'anima': {'acima', 'amima', 'anime', 'animo'},
#  'balir': {'balia', 'balis', 'baliu', 'banir', 'bulir'},
#  'Artur': set(),
#  'depus': set(),
#  'caviá': {'cavia', 'cavie', 'cavio'},
#  'emane': {'emana', 'emano'},
#  'adote': {'adite', 'adoce', 'adore', 'adota', 'adoto', 'anote'},
#  'amiga': {'amigo', 'amima'},
#  'desse': {'cesse', 'desce', 'desde', 'despe', 'dessa', 'deste', 'disse'},
#  'elevá': {'eleva', 'eleve', 'elevo'},
#  'atacá': {'ataca', 'ataco', 'atará'},
#  'dália': set(),
#  'capuz': {'capaz', 'caput'},
#  'brabo': {'braba', 'brado', 'bramo', 'bravo'},
#  'ceifa': {'ceife', 'ceifo', 'coifa'},
#  'afixe': {'afine', 'afixa', 'afixo'},
#  'cupim': {'capim', 'cupom'},
#  'disca': {'cisca', 'disco', 'dista'},
#  'cipós': set(),
#  'ameça': {'ameba', 'ameia', 'amena'},
#  'calça': {'calca', 'calda', 'calha', 'calma', 'calva', 'calço'},
#  'bigas': {'bagas', 'bicas', 'digas'},
#  'areia': {'ameia',
#   'apeia',
#   'ardia',
#   'areis',
#   'areja',
#   'arena',
#   'arria',
#   'ateia',
#   'aveia',
#   'creia'},
#  'bique': {'baque', 'beque', 'dique'},
#  'cagas': {'bagas',
#   'cacas',
#   'cagai',
#   'cagam',
#   'cagar',
#   'caias',
#   'calas',
#   'camas',
#   'canas',
#   'capas',
#   'caras',
#   'casas',
#   'catas',
#   'cavas',
#   'cegas'},
#  'doído': {'doado', 'doido', 'doída'},
#  'cedei': {'cedem', 'ceder', 'cedes', 'cedeu'},
#  'anulá': {'adulá', 'anelá', 'anula', 'anule', 'anulo', 'azulá'},
#  'boles': {'bales',
#   'bodes',
#   'bolas',
#   'bolei',
#   'bolem',
#   'bolos',
#   'botes',
#   'bules',
#   'coles'},
#  'citam': {'catam', 'citai', 'citar', 'citas', 'citem', 'cotam', 'ditam'},
#  'clamá': {'chamá', 'clama', 'clame', 'clamo'},
#  'apoiá': {'apoio'},
#  'eiras': {'erras'},
#  'cerra': {'berra',
#   'ceara',
#   'cerca',
#   'cerda',
#   'cerre',
#   'cerro',
#   'certa',
#   'corra'},
#  'bomba': {'bamba'},
#  'assoá': {'asseá', 'assoa', 'assoe', 'assou'},
#  'caber': {'cabei', 'cabem', 'cabes'},
#  'braço': {'brabo', 'brado', 'bramo', 'bravo', 'braça'},
#  'aulas': {'atlas', 'auras', 'bulas'},
#  'bagas': {'babas', 'bagos', 'baias', 'balas', 'batas', 'bigas', 'cagas'},
#  'aparo': {'amaro', 'apago', 'apara', 'apare', 'apuro', 'avaro', 'azaro'},
#  'burla': {'burle', 'burlo', 'burra'},
#  'canaã': {'canal', 'canas'},
#  'casam': {'cagam',
#   'caiam',
#   'calam',
#   'capam',
#   'casai',
#   'casal',
#   'casar',
#   'casas',
#   'casem',
#   'catam',
#   'cavam',
#   'cosam'},
#  'assôo': set(),
#  'atiná': {'afiná', 'atina', 'atine', 'atino', 'atirá', 'ativá'},
#  'achas': {'achai', 'acham', 'achar', 'aches', 'acuas'},
#  'alcei': {'alcem', 'alces', 'aliei'},
#  'disco': {'cisco', 'disca', 'disso', 'disto'},
#  'cuspo': {'culpo', 'cuspa', 'cuspi', 'custo'},
#  'cheio': {'checo', 'chego', 'cheia', 'creio'},
#  'bafos': {'bagos'},
#  'crivá': {'cravá', 'criva', 'crive', 'crivo'},
#  'alteá': {'alheá'},
#  'bolas': {'balas',
#   'belas',
#   'bobas',
#   'bocas',
#   'bodas',
#   'bolai',
#   'bolam',
#   'bolar',
#   'boles',
#   'bolos',
#   'botas',
#   'bulas',
#   'colas'},
#  'banes': {'babes',
#   'bales',
#   'banem',
#   'banis',
#   'bares',
#   'bases',
#   'bates',
#   'danes'},
#  'arria': {'abria', 'ardia', 'areia', 'arrie', 'arrio'},
#  'Chile': set(),
#  'durai': {'curai', 'duram', 'durar', 'duras', 'durei'},
#  'disso': {'disco', 'disse', 'disto'},
#  'brins': {'brios'},
#  'banal': {'canal'},
#  'barrá': {'barra', 'barre', 'barro', 'berrá', 'borrá'},
#  'calem': {'balem',
#   'cabem',
#   'cacem',
#   'caiem',
#   'calam',
#   'calei',
#   'cales',
#   'capem',
#   'casem',
#   'catem',
#   'cavem',
#   'colem'},
#  'advim': {'advir'},
#  'dutos': {'autos', 'ditos', 'duros'},
#  'curei': {'corei', 'curai', 'curem', 'cures', 'curti', 'durei'},
#  'Bielo': set(),
#  'cores': {'coces',
#   'coles',
#   'comes',
#   'cones',
#   'coras',
#   'corei',
#   'corem',
#   'coros',
#   'coses',
#   'cotes',
#   'cozes',
#   'cures',
#   'dores'},
#  'atada': {'alada', 'amada', 'arada', 'ataca', 'atado', 'atara', 'atava'},
#  'cabei': {'babei',
#   'cabem',
#   'caber',
#   'cabes',
#   'cacei',
#   'caiei',
#   'calei',
#   'capei',
#   'casei',
#   'catei',
#   'cavei'},
#  'ávida': {'ácida', 'árida', 'ávido'},
#  'cavar': {'cagar',
#   'caiar',
#   'calar',
#   'capar',
#   'casar',
#   'catar',
#   'cavai',
#   'cavam',
#   'cavas'},
#  'abono': {'abano'},
#  'cauta': {'canta',
#   'capta',
#   'carta',
#   'casta',
#   'cauda',
#   'causa',
#   'cauto',
#   'chuta'},
#  'chagá': {'chaga', 'chago', 'chamá', 'chegá'},
#  'colai': {'bolai',
#   'calai',
#   'colam',
#   'colar',
#   'colas',
#   'colei',
#   'colhi',
#   'corai',
#   'cotai'},
#  'apeia': {'ameia',
#   'apega',
#   'apeie',
#   'apeio',
#   'apela',
#   'apena',
#   'areia',
#   'ateia',
#   'aveia'},
#  'avimo': {'adimo', 'agimo', 'amimo', 'animo', 'aviso', 'avivo'},
#  'cívil': {'civil'},
#  'assai': {'assam', 'assar', 'assas', 'assaz', 'assei'},
#  'culta': {'celta', 'culpa', 'culto', 'curta', 'custa'},
#  'bicas': {'becas',
#   'bicai',
#   'bicam',
#   'bicar',
#   'bicos',
#   'bigas',
#   'bocas',
#   'dicas'},
#  'assis': {'assas', 'asses', 'assim'},
#  'bodes': {'bodas', 'boles', 'botes'},
#  'azule': {'adule', 'anule', 'azula', 'azulo'},
#  'caçou': {'cagou',
#   'caiou',
#   'calou',
#   'capou',
#   'casou',
#   'catou',
#   'cavou',
#   'caçoa',
#   'caçoe',
#   'coçou'},
#  'dotai': {'botai',
#   'cotai',
#   'datai',
#   'ditai',
#   'domai',
#   'dopai',
#   'dosai',
#   'dotam',
#   'dotar',
#   'dotas',
#   'dotei'},
#  'bolsa': {'balsa', 'bolha', 'bolso', 'bossa'},
#  'apare': {'apara', 'aparo', 'apure', 'azare'},
#  'acham': {'achai', 'achar', 'achas', 'achem', 'acuam'},
#  'avivá': {'ativá', 'avirá', 'avisá', 'aviva', 'avive', 'avivo'},
#  'beiro': {'beijo', 'beira', 'beire', 'berro'},
#  'aliam': {'adiam',
#   'afiam',
#   'agiam',
#   'aliai',
#   'aliar',
#   'alias',
#   'aliem',
#   'aviam'},
#  'cruzo': {'cruza', 'cruze'},
#  'cocos': {'cacos', 'coces', 'copos', 'coros', 'coxos', 'cucos'},
#  'asnos': set(),
#  'enche': {'encha', 'enchi', 'encho'},
#  'buscá': {'busca', 'busco'},
#  'capar': {'cagar',
#   'caiar',
#   'calar',
#   'capai',
#   'capam',
#   'capas',
#   'capaz',
#   'casar',
#   'catar',
#   'cavar'},
#  'ajudo': {'acudo', 'agudo', 'ajuda', 'ajude', 'aludo'},
#  'bater': {'batei', 'batel', 'batem', 'bates', 'bateu'},
#  'azede': {'azeda', 'azedo'},
#  'côdea': set(),
#  'cauto': {'cacto', 'canto', 'capto', 'casto', 'causo', 'cauta', 'chuto'},
#  'avisá': {'alisá', 'avirá', 'avisa', 'avise', 'aviso', 'avivá'},
#  'Cairo': set(),
#  'educá': {'educa', 'educo'},
#  'carga': {'canga', 'cargo', 'carpa', 'carta'},
#  'diria': {'daria', 'dizia'},
#  'coçai': {'caçai', 'colai', 'corai', 'cotai', 'coçam', 'coçar', 'coças'},
#  'corte': {'conte', 'coroe', 'corre', 'corta', 'corto', 'curte'},
#  'chata': {'chaga', 'chama', 'chapa', 'chato', 'chuta'},
#  'cesse': {'casse', 'cessa', 'cesso', 'desse'},
#  'animá': {'amimá', 'anima', 'anime', 'animo'},
#  'abrir': {'abria', 'abril', 'abris', 'abriu'},
#  'apagá': {'afagá', 'alagá', 'apaga', 'apago', 'apará', 'apegá'},
#  'erigi': {'erige'},
#  'enviá': {'enfiá', 'envia', 'envie', 'envio'},
#  'atado': {'alado', 'amado', 'arado', 'ataco', 'atada', 'atamo', 'atido'},
#  'clips': set(),
#  'avião': {'avimo', 'aviso', 'avivo'},
#  'abriu': {'abreu', 'abria', 'abril', 'abrir', 'abris'},
#  'apago': {'afago', 'alago', 'apaga', 'aparo', 'apego'},
#  'ditar': {'citar', 'datar', 'ditai', 'ditam', 'ditas', 'dotar'},
#  'baías': {'babas', 'bagas', 'baias', 'balas', 'batas', 'caías'},
#  'acata': {'abata', 'acaba', 'acate', 'acato'},
#  'áreas': {'árias'},
#  'afora': {'adora',
#   'afira',
#   'afoba',
#   'afofa',
#   'afoga',
#   'afore',
#   'aforo',
#   'agora'},
#  'datar': {'catar', 'danar', 'datai', 'datam', 'datas', 'ditar', 'dotar'},
#  'arcai': {'arcam', 'arcar', 'arcas', 'arfai', 'armai'},
#  'armas': {'almas',
#   'arcas',
#   'ardas',
#   'arfas',
#   'armai',
#   'armam',
#   'armar',
#   'armes'},
#  'acuar': {'achar', 'acuai', 'acuam', 'acuas', 'aguar', 'atuar'},
#  'calhe': {'calce', 'calha', 'calho', 'colhe'},
#  'brisa': {'brasa', 'brida', 'briga', 'brita'},
#  'enoja': {'enoje', 'enojo'},
#  'enjoá': {'enjoa', 'enjoe', 'entoá'},
#  'agimo': {'adimo', 'agido', 'agito', 'amimo', 'animo', 'avimo'},
#  'adies': {'adias', 'adiei', 'adiem', 'afies', 'alies', 'avies'},
#  'caves': {'cabes',
#   'caces',
#   'caies',
#   'cales',
#   'capes',
#   'cases',
#   'cates',
#   'cavas',
#   'cavei',
#   'cavem'},
#  'diodo': set(),
#  'atine': {'afine', 'atice', 'atina', 'atino', 'atire', 'ative'},
#  'amada': {'alada', 'amado', 'amara', 'amava', 'arada', 'atada'},
#  'abati': {'abata', 'abate', 'abato'},
#  'bufam': {'bufai', 'bufar', 'bufas', 'bufem', 'bulam'},
#  'acuem': {'achem', 'acuam', 'acuei', 'acues', 'aguem', 'anuem', 'atuem'},
#  'beija': {'beije', 'beijo', 'beira'},
#  'coram': {'colam',
#   'comam',
#   'corai',
#   'coral',
#   'corar',
#   'coras',
#   'corem',
#   'cosam',
#   'cotam',
#   'cozam',
#   'curam'},
#  'chovê': {'chova', 'chove', 'chovi', 'chovo'},
#  'envio': {'enfio', 'envia', 'envie'},
#  'dispô': set(),
#  'desço': {'desça'},
#  'babou': set(),
#  'domes': {'comes',
#   'domas',
#   'domei',
#   'domem',
#   'dopes',
#   'dores',
#   'doses',
#   'dotes'},
#  'afiro': {'adiro', 'afino', 'afira', 'afixo', 'aforo', 'atiro'},
#  'cabia': {'cabra', 'cavia'},
#  'criam': {'caiam', 'ceiam', 'chiam', 'criai', 'criar', 'crias', 'criem'},
#  'digas': {'bigas', 'dicas', 'digam', 'ditas', 'divas'},
#  'corto': {'certo',
#   'coito',
#   'conto',
#   'corno',
#   'corpo',
#   'corro',
#   'corta',
#   'corte',
#   'corvo',
#   'curto'},
#  'baliu': {'balia', 'balir', 'balis', 'baniu', 'buliu'},
#  'bruxa': {'bruma', 'bruta', 'bruxo'},
#  'erode': {'eroda', 'erodi', 'erodo'},
#  'bailo': {'baila', 'baile', 'baixo'},
#  'aquém': set(),
#  'dourá': {'doará', 'dobrá', 'doerá', 'doura', 'doure', 'douro'},
#  'barca': {'banca', 'barba', 'barco', 'barra'},
#  'cerco': {'cerca', 'cerro', 'certo', 'cervo', 'circo'},
#  'caiou': {'cagou',
#   'calou',
#   'capou',
#   'casou',
#   'catou',
#   'cavou',
#   'chiou',
#   'criou'},
#  'erodi': {'eroda', 'erode', 'erodo'},
#  'deram': {'deras', 'derem', 'devam', 'duram'},
#  'domem': {'comem', 'domam', 'domei', 'domes', 'dopem', 'dosem', 'dotem'},
#  'depõe': set(),
#  'chega': {'chaga', 'checa', 'chefa', 'chego', 'cheia'},
#  'ergam': {'ergas', 'erram'},
#  'afaná': {'abaná', 'afagá', 'afana', 'afane', 'afano', 'afiná'},
#  'cegam': {'cagam', 'cedam', 'cegai', 'cegar', 'cegas', 'ceiam'},
#  'almas': {'algas', 'alias', 'altas', 'alvas', 'armas'},
#  'abluo': {'ablua', 'ablui', 'afluo'},
#  'bonés': set(),
#  'curti': {'curai', 'curei', 'curta', 'curte', 'curto'},
#  'caçoa': {'canoa', 'caçoe', 'caçou'},
#  'alude': {'ajude', 'aluda', 'aludi', 'aludo'},
#  'coras': {'caras',
#   'ceras',
#   'colas',
#   'comas',
#   'copas',
#   'corai',
#   'coral',
#   'coram',
#   'corar',
#   'cores',
#   'coros',
#   'cosas',
#   'cotas',
#   'covas',
#   'coxas',
#   'cozas',
#   'curas'},
#  'átona': {'átono'},
#  'arpoe': {'arpoa'},
#  'anulo': {'adulo', 'anelo', 'anglo', 'anula', 'anule', 'azulo'},
#  'biela': set(),
#  'doure': {'dobre', 'doura', 'douro'},
#  'eleja': {'elejo', 'eleva'},
#  'aliem': {'adiem', 'afiem', 'alcem', 'aliam', 'aliei', 'alies', 'aviem'},
#  'atira': {'adira',
#   'afira',
#   'agira',
#   'atara',
#   'atina',
#   'atire',
#   'atiro',
#   'ativa',
#   'atura'},
#  'Bagdá': set(),
#  'chamá': {'chagá', 'chama', 'chame', 'chamo', 'clamá'},
#  'deita': {'deite', 'deito', 'deixa', 'delta', 'desta'},
#  'dúzia': {'dizia', 'dúbia'},
#  'domar': {'domai', 'domam', 'domas', 'dopar', 'dosar', 'dotar'},
#  'áurea': {'áureo'},
#  'cinja': {'canja', 'cinda', 'cinjo', 'cinta', 'cinza'},
#  'crave': {'chave', 'crava', 'cravo', 'crive'},
#  'atuns': {'atuas', 'atues'},
#  'dotar': {'botar',
#   'cotar',
#   'datar',
#   'ditar',
#   'domar',
#   'dopar',
#   'dosar',
#   'dotai',
#   'dotam',
#   'dotas'},
#  'crava': {'arava',
#   'brava',
#   'ceava',
#   'clava',
#   'coava',
#   'crave',
#   'cravo',
#   'criva'},
#  'coesa': {'coeso', 'coeva', 'coisa'},
#  'apite': {'adite', 'agite', 'apita', 'apito'},
#  'azeda': {'azede', 'azedo'},
#  'anuam': {'acuam', 'aguam', 'andam', 'anual', 'anuas', 'anuem', 'atuam'},
#  'bufou': set(),
#  'aptas': {'aftas', 'altas', 'antas', 'aptos'},
#  'aloje': {'alije', 'aloja', 'alojo'},
#  'aloja': {'alija', 'aloca', 'aloje', 'alojo'},
#  'beijo': {'beija', 'beije', 'beiro'},
#  'brevê': {'breve'},
#  'decai': set(),
#  'bolai': {'boiai', 'bolam', 'bolar', 'bolas', 'bolei', 'botai', 'colai'},
#  'atole': {'abole', 'amole', 'atola', 'atolo'},
#  'Cátia': set(),
#  'bufes': {'bufas', 'bufei', 'bufem', 'bules'},
#  'botei': {'batei',
#   'boiei',
#   'bolei',
#   'botai',
#   'botem',
#   'botes',
#   'cotei',
#   'dotei'},
#  'baias': {'babas', 'bagas', 'balas', 'batas', 'caias'},
#  'capim': {'capam', 'capem', 'cupim'},
#  'crias': {'caias',
#   'ceias',
#   'chias',
#   'criai',
#   'criam',
#   'criar',
#   'cries',
#   'cruas',
#   'cuias'},
#  'colei': {'bolei',
#   'calei',
#   'cocei',
#   'colai',
#   'colem',
#   'coles',
#   'colhi',
#   'comei',
#   'corei',
#   'cosei',
#   'cotei',
#   'cozei'},
#  'beire': {'beije', 'beira', 'beiro', 'berre'},
#  'bailá': {'baila', 'baile', 'bailo', 'baixá'},
#  'contá': {'cantá', 'congá', 'conta', 'conte', 'conto', 'cortá'},
#  'adora': {'adira', 'adore', 'adoro', 'adota', 'afora', 'agora'},
#  'apele': {'anele', 'apeie', 'apela', 'apelo', 'apene'},
#  'criai': {'caiai', 'chiai', 'criam', 'criar', 'crias', 'criei'},
#  'caiem': {'cabem',
#   'cacem',
#   'caiam',
#   'caiei',
#   'caies',
#   'calem',
#   'capem',
#   'casem',
#   'catem',
#   'cavem',
#   'ceiem',
#   'chiem',
#   'criem'},
#  'arfei': {'ardei', 'arfai', 'arfem', 'arfes', 'armei'},
#  'balas': {'babas',
#   'bagas',
#   'baias',
#   'balam',
#   'bales',
#   'balis',
#   'batas',
#   'belas',
#   'bolas',
#   'bulas',
#   'calas'},
#  'algas': {'alias', 'almas', 'altas', 'alvas'},
#  'cravo': {'bravo', 'crava', 'crave', 'crivo'},
#  'brida': {'brada', 'briga', 'brisa', 'brita'},
#  'calvo': {'calco', 'caldo', 'calho', 'calmo', 'calva'},
#  'cocei': {'cacei',
#   'cocem',
#   'coces',
#   'colei',
#   'comei',
#   'corei',
#   'cosei',
#   'cotei',
#   'cozei'},
#  'estas': {'essas', 'estai', 'estar'},
#  'chato': {'chago', 'chamo', 'chata', 'chuto'},
#  'custá': {'custa', 'custe', 'custo'},
#  'dirás': {'darás'},
#  'birra': {'barra', 'berra', 'borra', 'burra'},
#  'cures': {'cores', 'cumes', 'curas', 'curei', 'curem', 'dures'},
#  'clamo': {'ceamo', 'chamo', 'clama', 'clame', 'claro', 'coamo'},
#  'entro': {'antro', 'entra', 'entre'},
#  'erres': {'erras', 'errei', 'errem', 'erros'},
#  'chies': {'caies', 'ceies', 'chias', 'chiei', 'chiem', 'cries'},
#  'autuo': {'autua', 'autue'},
#  'atéia': {'ateia'},
#  'armai': {'arcai', 'arfai', 'armam', 'armar', 'armas', 'armei'},
#  'barão': {'babão',
#   'baião',
#   'balão',
#   'barco',
#   'bardo',
#   'barro',
#   'carão',
#   'darão'},
#  'apear': {'apeai', 'atear'},
#  'cassá': {'cansá', 'cassa', 'casse', 'casso', 'causá', 'cessá'},
#  'Diana': set(),
#  'braça': {'braba', 'brada', 'brama', 'brasa', 'brava', 'braço'},
#  'arena': {'acena', 'amena', 'apena', 'areia', 'areja', 'drena'},
#  'ardia': {'ardil', 'ardis', 'areia', 'arria'},
#  'curar': {'corar', 'curai', 'curam', 'curas', 'durar'},
#  'ecoei': {'ecoai', 'ecoem', 'ecoes'},
#  'ecoam': {'ecoai', 'ecoar', 'ecoas', 'ecoem'},
#  'borro': {'barro', 'berro', 'bordo', 'borra', 'borre', 'burro', 'corro'},
#  'diluo': {'dilua', 'dilui'},
#  'cromá': {'cremá', 'croma', 'crome', 'cromo'},
#  'afiou': {'adiou', 'aliou', 'aviou'},
#  'densa': {'denso', 'dessa', 'deusa'},
#  'dieta': {'dista'},
#  'cague': {'cegue'},
#  'casco': {'calco', 'casca', 'casso', 'casto', 'cisco'},
#  'capem': {'cabem',
#   'cacem',
#   'caiem',
#   'calem',
#   'capam',
#   'capei',
#   'capes',
#   'capim',
#   'casem',
#   'catem',
#   'cavem'},
#  'distá': {'discá', 'dista', 'diste', 'disto'},
#  'cruas': {'crias'},
#  'alves': {'alces', 'alies', 'alvas', 'alvos'},
#  'bancá': {'banca', 'banco', 'banhá'},
#  'afana': {'abana', 'afaga', 'afane', 'afano', 'afina'},
#  'atiço': {'atido', 'atino', 'atiro', 'ativo', 'atiça'},
#  'bania': {'bacia',
#   'balia',
#   'banca',
#   'banda',
#   'banha',
#   'banir',
#   'banis',
#   'baniu',
#   'batia'},
#  'afoba': {'afobe', 'afobo', 'afofa', 'afoga', 'afora'},
#  'dotas': {'botas',
#   'cotas',
#   'datas',
#   'ditas',
#   'docas',
#   'domas',
#   'donas',
#   'dopas',
#   'dosas',
#   'dotai',
#   'dotam',
#   'dotar',
#   'dotes'},
#  'certo': {'cento',
#   'cerco',
#   'cerro',
#   'certa',
#   'cervo',
#   'cesto',
#   'corto',
#   'curto'},
#  'bunde': {'bonde', 'bunda', 'bundo'},
#  'burra': {'barra', 'berra', 'birra', 'borra', 'burla', 'burro'},
#  'adula': {'aduba', 'adule', 'adulo', 'anula', 'azula'},
#  'coxim': set(),
#  'bicou': {'bicos'},
#  'bloco': {'aloco', 'broco'},
#  'aviar': {'adiar', 'afiar', 'aliar', 'aviai', 'aviam', 'avias', 'avier'},
#  'bordo': {'bardo', 'boldo', 'borda', 'borde', 'borro'},
#  'arará': {'amará', 'apará', 'arara', 'atará', 'azará'},
#  'andar': {'andai', 'andam', 'andas', 'andor'},
#  'ditem': {'citem', 'datem', 'ditam', 'ditei', 'dites', 'dizem', 'dotem'},
#  'ajude': {'ajuda', 'ajudo', 'alude'},
#  'aftas': {'afias', 'altas', 'antas', 'aptas'},
#  'alado': {'alada', 'alago', 'aludo', 'amado', 'arado', 'atado'},
#  'cursa': {'curse', 'curso', 'curta', 'curva'},
#  'brocá': {'brecá', 'broca', 'broco', 'brotá'},
#  'deste': {'deite',
#   'dente',
#   'desce',
#   'desde',
#   'despe',
#   'desse',
#   'desta',
#   'diste'},
#  'épica': {'épico', 'época'},
#  'deduz': set(),
#  'caixa': {'baixa', 'caiba'},
#  'bisão': {'bispo', 'cisão'},
#  'dúbia': {'dúbio', 'dúzia'},
#  'acaba': {'acabe', 'acabo', 'acata'},
#  'caído': {'caido', 'caldo', 'cardo', 'caída', 'caímo'},
#  'ditai': {'citai', 'datai', 'ditam', 'ditar', 'ditas', 'ditei', 'dotai'},
#  'adulo': {'adubo', 'adula', 'adule', 'anulo', 'azulo'},
#  'calor': {'calar', 'calos', 'calou'},
#  'acuam': {'acham',
#   'acuai',
#   'acuar',
#   'acuas',
#   'acuem',
#   'aguam',
#   'anuam',
#   'atuam'},
#  'corre': {'borre',
#   'cerre',
#   'cobre',
#   'cofre',
#   'coroe',
#   'corra',
#   'corri',
#   'corro',
#   'corte'},
#  'borre': {'barre', 'berre', 'borde', 'borra', 'borro', 'corre'},
#  'álamo': {'clamo'},
#  'aterá': {'atará', 'atirá', 'aturá'},
#  'brejo': {'arejo', 'breco'},
#  'escoá': {'escoa', 'escoe', 'escol'},
#  'babes': {'babas',
#   'babei',
#   'babem',
#   'bales',
#   'banes',
#   'bares',
#   'bases',
#   'bates',
#   'bebes',
#   'cabes'},
#  'coces': {'caces',
#   'cocei',
#   'cocem',
#   'cocos',
#   'coles',
#   'comes',
#   'cones',
#   'cores',
#   'coses',
#   'cotes',
#   'cozes'},
#  'despe': {'desce', 'desde', 'despi', 'desse', 'deste'},
#  'anota': {'adota', 'anote', 'anoto'},
#  'enojo': {'enoja', 'enoje'},
#  'choca': {'checa', 'choco', 'chora', 'chova'},
#  'Berta': {'Berna', 'certa'},
#  'doíam': {'domam', 'dopam', 'dosam', 'dotam', 'doías'},
#  'edema': set(),
#  'emulo': {'emula', 'emule'},
#  'calce': {'calca', 'calco', 'calhe'},
#  'anele': {'anela', 'anelo', 'anexe', 'anule', 'apele'},
#  'bando': {'banco', 'banda', 'banho', 'banjo', 'bardo', 'bundo', 'dando'},
#  'estás': {'estas'},
#  'cópia': {'copia'},
#  'corri': {'cobri', 'corai', 'corei', 'corra', 'corre', 'corro'},
#  'borda': {'borde', 'bordo', 'borra', 'corda'},
#  'baste': {'basta', 'basto'},
#  'deixá': {'deitá', 'deixa', 'deixe', 'deixo'},
#  'cruel': set(),
#  'Acaia': set(),
#  'banis': {'balis', 'banes', 'bania', 'banir', 'baniu'},
#  'aspas': {'assas'},
#  'andes': {'andas', 'andei', 'andem', 'antes', 'ardes'},
#  'ecoas': {'ecoai', 'ecoam', 'ecoar', 'ecoes'},
#  'acene': {'acena', 'aceno', 'apene'},
#  'ablui': {'ablua', 'abluo', 'aflui'},
#  'cuíca': {'cueca'},
#  'apara': {'amara',
#   'apaga',
#   'apare',
#   'aparo',
#   'apura',
#   'arara',
#   'atara',
#   'avara',
#   'azara'},
#  'dubla': {'duble', 'dublo', 'duela', 'dupla'},
#  'atido': {'adido', 'agido', 'amido', 'atado', 'atino', 'atiro', 'ativo'},
#  'bravo': {'brabo', 'brado', 'bramo', 'brava', 'cravo'},
#  'ecoai': {'ecoam', 'ecoar', 'ecoas', 'ecoei'},
#  'coagi': {'coage'},
#  'bufar': {'bufai', 'bufam', 'bufas'},
#  'bóies': {'bóias', 'bóiem'},
#  'andei': {'andai', 'andem', 'andes', 'ardei'},
#  'abate': {'abade',
#   'abafe',
#   'abale',
#   'abane',
#   'abata',
#   'abati',
#   'abato',
#   'acate'},
#  'busca': {'busco'},
#  'coava': {'ceava',
#   'clava',
#   'coada',
#   'coaja',
#   'coara',
#   'coaxa',
#   'coeva',
#   'crava',
#   'doava'},
#  'batam': {'babam',
#   'balam',
#   'batas',
#   'batem',
#   'batom',
#   'botam',
#   'catam',
#   'datam'},
#  'bundo': {'bando', 'bunda', 'bunde'},
#  'elixi': {'elixe', 'elixo'},
#  'duros': {'duras', 'dures', 'durou', 'dutos'},
#  'calcá': {'calca', 'calce', 'calco', 'calhá'},
#  'dublo': {'dubla', 'duble', 'duelo', 'duplo'},
#  'apito': {'adito', 'agito', 'apita', 'apite'},
#  'benzo': {'benza', 'benze', 'benzi'},
#  'acusa': {'abusa', 'acesa', 'acuda', 'acuse', 'acuso'},
#  'corno': {'corpo', 'corro', 'corto', 'corvo'},
#  'atuem': {'acuem', 'aguem', 'anuem', 'atuam', 'atuei', 'atues'},
#  'abusá': {'abusa', 'abuse', 'abuso', 'acusá'},
#  'anuis': {'anais', 'anuas', 'anuir', 'anuiu', 'azuis'},
#  'alçam': {'aliam', 'alçai', 'alçar', 'alças'},
#  'acolá': {'amolá', 'atolá'},
#  'cheia': {'checa', 'chefa', 'chega', 'cheio', 'creia'},
#  'chias': {'caias',
#   'ceias',
#   'chiai',
#   'chiam',
#   'chiar',
#   'chies',
#   'crias',
#   'cuias'},
#  'catei': {'batei',
#   'cabei',
#   'cacei',
#   'caiei',
#   'calei',
#   'capei',
#   'casei',
#   'catai',
#   'catem',
#   'cates',
#   'cavei',
#   'citei',
#   'cotei',
#   'datei'},
#  'coeso': {'coemo', 'coesa', 'coevo'},
#  'blefe': {'blefa', 'blefo'},
#  'alocá': {'aloca', 'aloco', 'alojá'},
#  'China': {'Chica'},
#  'deres': {'dares', 'deles', 'deras', 'derem', 'deves', 'dores', 'dures'},
#  'anzol': set(),
#  'casei': {'cabei',
#   'cacei',
#   'caiei',
#   'calei',
#   'capei',
#   'casai',
#   'casem',
#   'cases',
#   'catei',
#   'cavei',
#   'cosei'},
#  'autos': {'altos', 'aptos', 'autor', 'dutos'},
#  'alada': {'alado', 'alaga', 'aluda', 'amada', 'arada', 'atada'},
#  'diabo': set(),
#  'aludo': {'acudo',
#   'agudo',
#   'ajudo',
#   'alado',
#   'aluda',
#   'alude',
#   'aludi',
#   'alugo',
#   'aluno'},
#  'cabes': {'babes',
#   'cabei',
#   'cabem',
#   'caber',
#   'cabos',
#   'caces',
#   'caies',
#   'cales',
#   'capes',
#   'cases',
#   'cates',
#   'caves'},
#  'aluda': {'acuda',
#   'aguda',
#   'ajuda',
#   'alada',
#   'alude',
#   'aludi',
#   'aludo',
#   'aluga',
#   'aluna'},
#  'Esopo': set(),
#  'anoto': {'adoto', 'anota', 'anote', 'azoto'},
#  'arfai': {'arcai', 'arfam', 'arfar', 'arfas', 'arfei', 'armai'},
#  'cavia': {'cabia', 'cavie', 'cavio'},
#  'encho': {'encha', 'enche', 'enchi'},
#  'coifa': {'ceifa', 'coisa'},
#  'daria': {'diria'},
#  'cueca': {'checa'},
#  'Dácia': set(),
#  'aveio': {'apeio', 'ateio', 'aveia'},
#  'éreis': {'areis'},
#  'anuiu': {'anuir', 'anuis'},
#  'chupa': {'chapa', 'chupe', 'chupo', 'chuta', 'chuva'},
#  'anual': {'anuam', 'anuas', 'atual'},
#  'cisão': {'bisão', 'cisco', 'cismo'},
#  'cotar': {'botar',
#   'catar',
#   'citar',
#   'colar',
#   'corar',
#   'cotai',
#   'cotam',
#   'cotas',
#   'dotar'},
#  'ancas': {'andas', 'antas', 'anuas', 'arcas'},
#  'berra': {'barra',
#   'beira',
#   'berre',
#   'berro',
#   'birra',
#   'borra',
#   'burra',
#   'cerra'},
#  'anula': {'adula', 'anela', 'anule', 'anulo', 'azula'},
#  'alija': {'alije', 'alijo', 'alisa', 'aloja'},
#  'Dacca': set(),
#  'aludi': {'acudi', 'aluda', 'alude', 'aludo'},
#  'derem': {'darem', 'deram', 'deres', 'devem', 'durem'},
#  'coseu': {'comeu', 'cosei', 'cosem', 'coser', 'coses', 'cozeu'},
#  'brito': {'brigo', 'brita', 'broto', 'bruto'},
#  'bueno': set(),
#  'enchi': {'encha', 'enche', 'encho'},
#  'citas': {'catas', 'citai', 'citam', 'citar', 'cites', 'cotas', 'ditas'},
#  'assei': {'assai', 'assem', 'asses'},
#  'aguçá': {'aguça', 'aguço'},
#  'cauda': {'calda', 'causa', 'cauta'},
#  'emite': {'elite', 'emita', 'emiti', 'emito'},
#  'acode': set(),
#  'caras': {'cacas',
#   'cagas',
#   'caias',
#   'calas',
#   'camas',
#   'canas',
#   'capas',
#   'caros',
#   'casas',
#   'catas',
#   'cavas',
#   'ceras',
#   'coras',
#   'curas'},
#  'bastá': {'baseá', 'basta', 'baste', 'basto'},
#  'culpa': {'culpe', 'culpo', 'culta', 'cuspa'},
#  'afies': {'adies', 'afias', 'afiei', 'afiem', 'afins', 'alies', 'avies'},
#  'cifrá': {'cifra', 'cifre', 'cifro'},
#  'arejo': {'areja', 'areje', 'aremo', 'brejo'},
#  'ditos': {'ditas', 'dites', 'ditou', 'dutos'},
#  'ergue': {'ergui'},
#  'armei': {'ardei', 'arfei', 'armai', 'armem', 'armes'},
#  'alces': {'alcei', 'alcem', 'alies', 'alves'},
#  'aderi': {'adere', 'aferi'},
#  'cairá': set(),
#  'cacos': {'cabos',
#   'cacas',
#   'caces',
#   'calos',
#   'canos',
#   'caros',
#   'casos',
#   'cocos',
#   'cucos'},
#  'coisa': {'coesa', 'coifa'},
#  'celas': {'belas',
#   'calas',
#   'cedas',
#   'cegas',
#   'ceias',
#   'cenas',
#   'ceras',
#   'colas',
#   'delas'},
#  'darei': {'danei', 'darem', 'dares', 'datei', 'direi', 'durei'},
#  'essas': {'assas', 'esses', 'estas'},
#  'dólar': set(),
#  'checo': {'checa', 'chego', 'cheio', 'choco'},
#  'apeio': {'apego',
#   'apeia',
#   'apeie',
#   'apelo',
#   'apeno',
#   'apoio',
#   'ateio',
#   'aveio'},
#  'elevo': {'elejo', 'eleva', 'eleve'},
#  'danes': {'banes', 'danas', 'danei', 'danem', 'danos', 'dares', 'dates'},
#  'enfio': {'enfia', 'enfie', 'enfim', 'envio'},
#  'areal': set(),
#  'avies': {'adies', 'afies', 'alies', 'avias', 'aviei', 'aviem', 'avier'},
#  'acuei': {'achei', 'acuai', 'acudi', 'acuem', 'acues', 'aguei', 'atuei'},
#  'ateio': {'apeio', 'ateia', 'ateie', 'ateis', 'atemo', 'aveio'},
#  'bares': {'babes', 'bales', 'banes', 'bases', 'bates', 'dares'},
#  'edita': {'adita', 'edito', 'emita'},
#  'avise': {'alise', 'avisa', 'aviso', 'avive'},
#  'capto': {'cacto', 'canto', 'capta', 'capte', 'casto', 'cauto'},
#  'areja': {'areia', 'areje', 'arejo', 'arena'},
#  'cupom': {'cupim'},
#  'dueto': {'duelo'},
#  'atara': {'amara',
#   'apara',
#   'arara',
#   'ataca',
#   'atada',
#   'atava',
#   'atira',
#   'atura',
#   'avara',
#   'azara'},
#  'adoro': {'adiro', 'adora', 'adore', 'adoto', 'aforo'},
#  'entôo': {'enjôo', 'entro'},
#  'ateia': {'ameia', 'apeia', 'areia', 'ateie', 'ateio', 'ateis', 'aveia'},
#  'dopam': {'domam', 'dopai', 'dopar', 'dopas', 'dopem', 'dosam', 'dotam'},
#  'direi': {'darei', 'ditei', 'dizei', 'durei'},
#  'cites': {'cates', 'citas', 'citei', 'citem', 'cotes', 'dites'},
#  'deixa': {'deita', 'deixe', 'deixo'},
#  'Braga': {'draga'},
#  'duele': {'duble', 'duela', 'duelo'},
#  'crede': {'credo', 'creme'},
#  'arfem': {'ardem', 'arfam', 'arfei', 'arfes', 'armem'},
#  'ataco': {'ataca', 'atado', 'atamo'},
#  'banhe': {'banha', 'banho'},
#  'atuar': {'acuar', 'aguar', 'atear', 'atuai', 'atual', 'atuam', 'atuas'},
#  'assas': {'aspas',
#   'assai',
#   'assam',
#   'assar',
#   'assaz',
#   'asses',
#   'assis',
#   'essas'},
#  'cujos': {'cubos', 'cucos', 'cujas', 'cujus'},
#  'bazar': {'babar'},
#  'agito': {'adito', 'agido', 'agimo', 'agita', 'agite', 'apito'},
#  'árduo': {'árdua'},
#  'couro': {'cobro', 'corro', 'douro'},
#  'arguo': {'argua'},
#  'erodo': {'eroda', 'erode', 'erodi'},
#  'Belém': set(),
#  'caido': {'caibo', 'caldo', 'cardo', 'crido', 'cuido'},
#  'beber': {'bebei', 'bebem', 'bebes', 'bebeu'},
#  'durou': {'curou', 'duros'},
#  'André': set(),
#  'bruxo': {'bruto', 'bruxa'},
#  'afobá': {'afoba', 'afobe', 'afobo', 'afofá', 'afogá', 'aforá'},
#  'aboli': {'abole'},
#  'domas': {'comas',
#   'damas',
#   'docas',
#   'domai',
#   'domam',
#   'domar',
#   'domes',
#   'donas',
#   'dopas',
#   'dosas',
#   'dotas',
#   'dumas'},
#  'entoa': {'enjoa', 'entoe', 'entra'},
#  'adido': {'adida', 'adimo', 'adiro', 'adito', 'agido', 'amido', 'atido'},
#  'chale': {'chame', 'chave'},
#  'asseá': {'assei', 'assem', 'asses', 'assoá'},
#  'apuro': {'aparo', 'apura', 'apure', 'aturo'},
#  'afiar': {'adiar', 'afiai', 'afiam', 'afias', 'aliar', 'aviar'},
#  'boiai': {'boiar', 'boiei', 'bolai', 'botai'},
#  'Elisa': {'Elixa', 'alisa'},
#  'cotam': {'botam',
#   'catam',
#   'citam',
#   'colam',
#   'comam',
#   'coram',
#   'cosam',
#   'cotai',
#   'cotar',
#   'cotas',
#   'cotem',
#   'cozam',
#   'dotam'},
#  'dadas': {'dados', 'damas', 'danas', 'datas', 'davas'},
#  'abris': {'abras', 'abres', 'abria', 'abril', 'abrir', 'abriu'},
#  'amima': {'acima', 'amiga', 'amime', 'amimo', 'anima'},
#  'erguê': {'ergue', 'ergui'},
#  'demos': {'damos', 'dedos'},
#  'cargo': {'cardo', 'carga', 'carmo', 'carro'},
#  'doses': {'coses',
#   'domes',
#   'dopes',
#   'dores',
#   'dosas',
#   'dosei',
#   'dosem',
#   'dotes'},
#  'eixos': set(),
#  'arada': {'alada', 'amada', 'arado', 'arara', 'arava', 'atada', 'brada'},
#  'bolos': {'belos', 'bobos', 'bolas', 'boles', 'bolou'},
#  'elite': {'elixe', 'emite'},
#  'cavei': {'cabei',
#   'cacei',
#   'caiei',
#   'calei',
#   'capei',
#   'casei',
#   'catei',
#   'cavai',
#   'cavem',
#   'caves'},
#  'domou': {'dopou', 'dosou', 'dotou'},
#  'canso': {'cansa', 'canse', 'canto', 'casso', 'causo', 'censo'},
#  'afetá': {'afeta', 'afete', 'afeto'},
#  'coaxa': {'coada', 'coaja', 'coara', 'coava', 'coaxe', 'coaxo'},
#  'avirá': {'adirá', 'agirá', 'atirá', 'avisá', 'avivá'},
#  'despi': {'desci', 'despe'},
#  'burlo': {'burgo', 'burla', 'burle', 'burro'},
#  'erram': {'ergam', 'errai', 'errar', 'erras', 'errem'},
#  'cedes': {'cedas', 'cedei', 'cedem', 'ceder', 'cedeu', 'ceies'},
#  'bocha': {'bicha', 'bolha', 'bucha'},
#  'cuido': {'caido', 'crido', 'cuida', 'cuide'},
#  'apegá': {'alegá', 'apagá', 'apega', 'apego', 'apelá', 'apená'},
#  'corça': {'corda', 'corja', 'coroa', 'corra', 'corta'},
#  'alçai': {'aliai', 'alçam', 'alçar', 'alças'},
#  'dopem': {'domem', 'dopam', 'dopei', 'dopes', 'dosem', 'dotem'},
#  'asile': {'asila', 'asilo'},
#  'berro': {'barro', 'beiro', 'berra', 'berre', 'borro', 'burro', 'cerro'},
#  'ciscá': {'cisca', 'cisco', 'cismá', 'discá'},
#  'caíam': {'cagam',
#   'caiam',
#   'calam',
#   'capam',
#   'casam',
#   'catam',
#   'cavam',
#   'caías'},
#  'ainda': {'cinda'},
#  'coage': {'coagi', 'coaxe'},
#  'benzi': {'benza', 'benze', 'benzo'},
#  'anais': {'ajais', 'amais', 'anuis', 'arais', 'atais', 'avais'},
#  'caiai': {'cagai',
#   'caiam',
#   'caiar',
#   'caias',
#   'caiei',
#   'calai',
#   'capai',
#   'casai',
#   'catai',
#   'cavai',
#   'chiai',
#   'criai'},
#  'dando': {'bando', 'dardo'},
#  'ceava': {'ceara', 'clava', 'coava', 'crava'},
#  'cozas': {'colas',
#   'comas',
#   'copas',
#   'coras',
#   'cosas',
#   'cotas',
#   'covas',
#   'coxas',
#   'cozam',
#   'cozes'},
#  'chuto': {'cauto', 'chato', 'chupo', 'chuta', 'chute'},
#  'ceeis': {'ceais', 'coeis'},
#  'afino': {'afano', 'afina', 'afine', 'afins', 'afiro', 'afixo', 'atino'},
#  'casto': {'basto',
#   'cacto',
#   'canto',
#   'capto',
#   'casco',
#   'casso',
#   'casta',
#   'cauto',
#   'cesto',
#   'custo'},
#  'benza': {'benta', 'benze', 'benzi', 'benzo'},
#  'ardis': {'arais', 'ardas', 'ardes', 'ardia', 'ardil', 'areis'},
#  'acabo': {'acaba', 'acabe', 'acaso', 'acato'},
#  'drená': {'drena', 'drene', 'dreno'},
#  'citem': {'catem', 'citam', 'citei', 'cites', 'cotem', 'ditem'},
#  'darás': {'dares', 'dirás'},
#  'cries': {'caies', 'ceies', 'chies', 'crias', 'criei', 'criem'},
#  'anexo': {'anelo', 'anexa', 'anexe'},
#  'barre': {'barra', 'barro', 'berre', 'borre'},
#  'durar': {'curar', 'durai', 'duram', 'duras'},
#  'afiai': {'adiai', 'afiam', 'afiar', 'afias', 'afiei', 'aliai', 'aviai'},
#  'baseá': {'baleá', 'bases', 'bastá'},
#  'adite': {'adita', 'adito', 'adote', 'agite', 'apite'},
#  'armem': {'ardem', 'arfem', 'armam', 'armei', 'armes'},
#  'águia': set(),
#  'afete': {'afere', 'afeta', 'afeto'},
#  'bramá': {'bradá', 'brama', 'brame', 'brami', 'bramo'},
#  'coais': {'ceais', 'coeis', 'doais'},
#  'árdua': {'árduo'},
#  'brame': {'arame', 'brade', 'brama', 'brami', 'bramo'},
#  'arais': {'ajais', 'amais', 'anais', 'ardis', 'areis', 'atais', 'avais'},
#  'capam': {'cagam',
#   'caiam',
#   'calam',
#   'capai',
#   'capar',
#   'capas',
#   'capaz',
#   'capem',
#   'capim',
#   'casam',
#   'catam',
#   'cavam'},
#  'afixo': {'afino', 'afiro', 'afixa', 'afixe'},
#  'cotai': {'botai',
#   'catai',
#   'citai',
#   'colai',
#   'corai',
#   'cotam',
#   'cotar',
#   'cotas',
#   'cotei',
#   'dotai'},
#  'arpoá': {'arpoa', 'arpoe'},
#  'compô': set(),
#  'dance': {'dante'},
#  'Dhaka': set(),
#  'curas': {'auras',
#   'caras',
#   'ceras',
#   'coras',
#   'cubas',
#   'cucas',
#   'cuias',
#   'cujas',
#   'curai',
#   'curam',
#   'curar',
#   'cures',
#   'duras'},
#  'apitá': {'aditá', 'agitá', 'apita', 'apite', 'apito'},
#  'dublá': {'dubla', 'duble', 'dublo', 'duelá'},
#  'argúi': set(),
#  'catai': {'cagai',
#   'caiai',
#   'calai',
#   'capai',
#   'casai',
#   'catam',
#   'catar',
#   'catas',
#   'catei',
#   'cavai',
#   'citai',
#   'cotai',
#   'datai'},
#  'ejeto': {'ejeta', 'ejete', 'ereto'},
#  'árida': {'brida', 'ácida', 'árido', 'ávida'},
#  'crema': {'creia', 'creme', 'cremo', 'crera', 'croma'},
#  'asilo': {'asila', 'asile'},
#  'erros': {'ermos', 'erras', 'erres', 'errou'},
#  'armou': {'arcou', 'arfou'},
#  'civis': {'civil'},
#  'enoje': {'enoja', 'enojo'},
#  'bujão': {'bufão'},
#  'cavem': {'cabem',
#   'cacem',
#   'caiem',
#   'calem',
#   'capem',
#   'casem',
#   'catem',
#   'cavam',
#   'cavei',
#   'caves'},
#  'carro': {'barro', 'cardo', 'cargo', 'carmo', 'cerro', 'corro'},
#  'arpoa': {'arpoe'},
#  'azedá': {'azeda', 'azede', 'azedo'},
#  'cesto': {'casto', 'cento', 'certo', 'cesso', 'cesta', 'custo'},
#  'alhos': {'altos', 'alvos'},
#  'cílio': {'círio'},
#  'apega': {'adega', 'alega', 'apaga', 'apego', 'apeia', 'apela', 'apena'},
#  'bucha': {'bicha', 'bocha', 'bucho', 'ducha'},
#  'batas': {'babas',
#   'bagas',
#   'baias',
#   'balas',
#   'batam',
#   'bates',
#   'botas',
#   'catas',
#   'datas'},
#  'aviam': {'adiam',
#   'afiam',
#   'agiam',
#   'aliam',
#   'aviai',
#   'aviar',
#   'avias',
#   'aviem'},
#  'Dario': set(),
#  'acaso': {'acabo', 'acato', 'aceso', 'acuso'},
#  'dotes': {'botes',
#   'cotes',
#   'dates',
#   'dites',
#   'domes',
#   'dopes',
#   'dores',
#   'doses',
#   'dotas',
#   'dotei',
#   'dotem'},
#  'calhá': {'calcá', 'calha', 'calhe', 'calho'},
#  'chorá': {'chocá', 'chora', 'chore', 'choro'},
#  'amolo': {'amola', 'amole', 'amplo', 'apolo', 'atolo'},
#  'emito': {'edito', 'emita', 'emite', 'emiti'},
#  'ciclo': set(),
#  'emaná': {'emana', 'emane', 'emano'},
#  'cozes': {'coces',
#   'coles',
#   'comes',
#   'cones',
#   'cores',
#   'coses',
#   'cotes',
#   'cozas',
#   'cozei',
#   'cozem',
#   'cozer',
#   'cozeu'},
#  'curta': {'carta',
#   'certa',
#   'corta',
#   'culta',
#   'cursa',
#   'curte',
#   'curti',
#   'curto',
#   'curva',
#   'custa'},
#  'adore': {'adere', 'adoce', 'adora', 'adoro', 'adote', 'afore'},
#  'drena': {'arena', 'drene', 'dreno'},
#  'dirão': {'darão'},
#  'chiai': {'caiai', 'chiam', 'chiar', 'chias', 'chiei', 'criai'},
#  'âmbar': set(),
#  'ceife': {'ceifa', 'ceifo'},
#  'dizia': {'diria'},
#  'doará': {'coará', 'doara', 'dobrá', 'doerá', 'dourá'},
#  'corai': {'colai',
#   'coral',
#   'coram',
#   'corar',
#   'coras',
#   'corei',
#   'corri',
#   'cotai',
#   'curai'},
#  'Elias': {'alias'},
#  'copas': {'capas',
#   'colas',
#   'comas',
#   'copos',
#   'coras',
#   'cosas',
#   'cotas',
#   'covas',
#   'coxas',
#   'cozas',
#   'dopas'},
#  'atamo': {'ajamo', 'amamo', 'aramo', 'ataco', 'atado', 'atemo'},
#  'ecoou': set(),
#  'arcos': {'arcas', 'arcou'},
#  'clero': {'claro', 'cloro'},
#  'abres': {'abras', 'abrem', 'abreu', 'abris'},
#  'catar': {'cagar',
#   'caiar',
#   'calar',
#   'capar',
#   'casar',
#   'catai',
#   'catam',
#   'catas',
#   'cavar',
#   'citar',
#   'cotar',
#   'datar'},
#  'épico': {'épica'},
#  'conta': {'canta', 'cinta', 'conte', 'conto', 'corta', 'costa'},
#  'caçoá': {'caçoa', 'caçoe', 'caçou'},
#  'acatá': {'acabá', 'acata', 'acate', 'acato'},
#  'alugo': {'alago', 'alego', 'aludo', 'aluga', 'aluno'},
#  'dosas': {'cosas',
#   'docas',
#   'domas',
#   'donas',
#   'dopas',
#   'dosai',
#   'dosam',
#   'dosar',
#   'doses',
#   'dotas'},
#  'chamo': {'ceamo', 'chago', 'chama', 'chame', 'chato', 'clamo', 'coamo'},
#  'apena': {'acena',
#   'amena',
#   'apega',
#   'apeia',
#   'apela',
#   'apene',
#   'apeno',
#   'arena'},
#  'ébrio': set(),
#  'alemã': set(),
#  'deveu': {'devei', 'devem', 'dever', 'deves'},
#  'comas': {'camas',
#   'colas',
#   'comam',
#   'comes',
#   'copas',
#   'coras',
#   'cosas',
#   'cotas',
#   'covas',
#   'coxas',
#   'cozas',
#   'domas'},
#  'afixá': {'afiná', 'afixa', 'afixe', 'afixo'},
#  'Accra': set(),
#  'blefá': {'blefa', 'blefe', 'blefo'},
#  'criar': {'caiar', 'chiar', 'criai', 'criam', 'crias'},
#  'custa': {'casta',
#   'cesta',
#   'costa',
#   'culta',
#   'curta',
#   'cuspa',
#   'custe',
#   'custo'},
#  'aluga': {'alaga', 'alega', 'aluda', 'alugo', 'aluna'},
#  'chaga': {'chago', 'chama', 'chapa', 'chata', 'chega'},
#  'cuida': {'cuide', 'cuido'},
#  'citei': {'catei', 'citai', 'citem', 'cites', 'cotei', 'ditei'},
#  'cavas': {'cacas',
#   'cagas',
#   'caias',
#   'calas',
#   'camas',
#   'canas',
#   'capas',
#   'caras',
#   'casas',
#   'catas',
#   'cavai',
#   'cavam',
#   'cavar',
#   'caves',
#   'covas',
#   'davas'},
#  'chutá': {'chupá', 'chuta', 'chute', 'chuto'},
#  'capei': {'cabei',
#   'cacei',
#   'caiei',
#   'calei',
#   'capai',
#   'capem',
#   'capes',
#   'casei',
#   'catei',
#   'cavei'},
#  'apelo': {'anelo', 'apego', 'apeio', 'apela', 'apele', 'apeno', 'apolo'},
#  'alegá': {'alagá', 'alega', 'alego', 'alugá', 'apegá'},
#  'bruta': {'brita', 'brota', 'bruma', 'bruto', 'bruxa'},
#  'cegas': {'cagas',
#   'cedas',
#   'cegai',
#   'cegam',
#   'cegar',
#   'cegos',
#   'ceias',
#   'celas',
#   'cenas',
#   'ceras'},
#  'deite': {'deita', 'deito', 'deixe', 'dente', 'deste'},
#  'acená': {'acena', 'acene', 'aceno', 'apená'},
#  'dados': {'dadas', 'damos', 'danos', 'dedos'},
#  'coara': {'ceara',
#   'clara',
#   'coada',
#   'coaja',
#   'coava',
#   'coaxa',
#   'cobra',
#   'corra',
#   'doara'},
#  'cosia': {'comia', 'copia', 'costa', 'cozia'},
#  'dragá': {'draga', 'drago', 'drogá'},
#  'bebes': {'babes', 'bebas', 'bebei', 'bebem', 'beber', 'bebeu'},
#  'argüi': set(),
#  'danai': {'danam', 'danar', 'danas', 'danei', 'datai'},
#  'damos': {'dados', 'damas', 'danos', 'demos'},
#  'ésima': {'ésimo'},
#  'ergas': {'ergam', 'erras', 'ervas'},
#  'decaí': {'decai'},
#  'doado': {'coado', 'doada', 'doamo', 'doido'},
#  'creio': {'cheio', 'credo', 'creia', 'cremo'},
#  'afore': {'adore', 'afere', 'afobe', 'afofe', 'afora', 'aforo'},
#  'cercá': {'cerca', 'cerco', 'cerrá'},
#  'bordá': {'borda', 'borde', 'bordo', 'borrá'},
#  'circo': {'cerco', 'cinco', 'cisco'},
#  'apura': {'apara', 'apure', 'apuro', 'atura'},
#  'amamo': {'ajamo', 'amado', 'amaro', 'amemo', 'amimo', 'aramo', 'atamo'},
#  'bundá': {'bunda', 'bunde', 'bundo'},
#  'ardeu': {'ardei', 'ardem', 'arder', 'ardes'},
#  'captá': {'cantá', 'capta', 'capte', 'capto'},
#  'apeai': {'apear', 'apeei', 'ateai'},
#  'cobra': {'cabra',
#   'coara',
#   'cobre',
#   'cobri',
#   'cobro',
#   'corra',
#   'cubra',
#   'dobra'},
#  'arcar': {'arcai', 'arcam', 'arcas', 'arfar', 'armar'},
#  'ciosa': {'cioso'},
#  'emule': {'emula', 'emulo'},
#  'bebam': {'babam', 'bebas', 'bebem'},
#  'adita': {'adida',
#   'adira',
#   'adite',
#   'adito',
#   'adota',
#   'agita',
#   'apita',
#   'edita'},
#  'emita': {'edita', 'emite', 'emiti', 'emito'},
#  'amolá': {'acolá', 'amola', 'amole', 'amolo', 'atolá'},
#  'autuá': {'autua', 'autue', 'autuo'},
#  'aloés': set(),
#  'anjos': set(),
#  'aguou': {'acuou', 'atuou'},
#  'brigo': {'briga', 'brito'},
#  'cavie': {'cavia', 'cavio'},
#  'broca': {'breca', 'broco', 'brota'},
#  'bicos': {'becos', 'bicas', 'bicou'},
#  'azare': {'apare', 'azara', 'azaro'},
#  'espiá': {'espia', 'espie', 'espio'},
#  'brami': {'brama', 'brame', 'bramo'},
#  'abala': {'abafa', 'abale', 'abalo', 'abana', 'abata'},
#  'escoa': {'escoe', 'escol'},
#  'cerca': {'cerco', 'cerda', 'cerra', 'certa'},
#  'abade': {'abafe', 'abale', 'abane', 'abate'},
#  'ânsia': set(),
#  'cucos': {'cacos', 'cocos', 'cubos', 'cucas', 'cujos'},
#  'afofa': {'afoba', 'afofe', 'afofo', 'afoga', 'afora'},
#  'drene': {'drena', 'dreno'},
#  ...}

# %% [markdown]
# * Agora podemos usar a **busca em largura** para resolver o problema em questão:

# %%
breadth_first('dizes', 'chapa', palavras_vizinhas )
# Out:
# ['dizes',
#  'dizei',
#  'direi',
#  'durei',
#  'curei',
#  'curti',
#  'curta',
#  'carta',
#  'cauta',
#  'chuta',
#  'chupa',
#  'chapa']

# %%
breadth_first('dizes', 'chapa', palavras_vizinhas )
# Out:
# ['dizes',
#  'dizei',
#  'direi',
#  'durei',
#  'curei',
#  'curti',
#  'curta',
#  'carta',
#  'cauta',
#  'chuta',
#  'chupa',
#  'chapa']
