# %% [markdown]
# **Instituto de Informática - UFG**
#
# Disciplina: Inteligência Computacional
#
# Prof. Cedric Luiz de Carvalho
#
# Aluna(o):
#
#
#
# ---
# Aluna(o):
#
#
#
# ---

# %% [markdown]
# #Especificação do problema : Turismo pelo Brasil

# %% [markdown]
# * Uma empresa operadora de turismo deseja identificar a melhor rota para uma viagem rodoviária pelas capitais brasileiras, de forma a baratear seus pacotes turísticos e aumentar seus lucros. Desta forma, contratou a sua equipe para desenvolver uma solução computacional para o problema. Foi sugerido que fossem usados os dados disponíveis no portal: [Itatrans](http://www.itatrans.com.br/distancia.html), os quais quais estão sistematizados no arquivo **capitais.csv.**
#
# * A porção inferior da planilha (células abaixo daquela com valor 0), traz à distância rodoviária entre as cidades. A porção superior, indica as distâncias aéreas entre as cidades.
#
# * Considere que o mapa a seguir indique as conexões rodoviárias entre as capitais.  As conexões diretas entre as cidades estão indicadas no arquivo **conexCapitais.csv**

# %%
# !mkdir img/

# %%
# !mv mapa-brasil-estados-capitais.jpg img/

# %%
from IPython.display import Image
Image("img/mapa-brasil-estados-capitais.jpg")

# %% [markdown]
# *  Defina um modelo para este problema.
# *  Construa uma implementação computacional para a solução do problema, utilizando as seguintes estratégias:
#
#      1.   Busca em aprofundamento iterativo
#      2.   Busca de custo uniforme (considerar a distância rodoviária entre as cidades como o custo do caminho entre elas)
#
#      3.   Busca A\*
#      4.   Busca IDA*
#
# * Para cada estratégia implementada, meça o tempo gasto para encontrar a solução e o espaço de armazenamento utilizado (número de nós gerados).
#
# * Considere como custo do caminho a distância rodoviária entre as cidades.
#
# * Considere como heurística a distância aérea entre as cidades (distância em linha reta)
#
# * Apresente graficamente os resultados e faça uma análise criteriosa comparando os métodos utilizados.

# %% [markdown]
# ## O trabalho

# %% [markdown]
# O trabalho deve ser feito em grupos, conforme definido. Cada grupo deverá entregar apenas um produto final para ser avaliado pelo professor. Apesar do trabalho ser feito em grupos, a avaliação de cada aluno será feita individualmente.

# %% [markdown]
# **Recomendações:**
#
#    O primeiro passo para resolver um problema é entendê-lo muito bem, considerar o contexto e fazer as abstrações necessárias. A seguir, para não "reinventar a roda" é preciso identificar como a comunidade resolveu o problema em questão, ou problemas parecidos, cuja solução possa ser mapeada para situação em análise. Desta forma, deve ser feito um estudo, o mais amplo possível sobre esse assunto. O próximo passo é o grupo se reunir e instanciar o modelo em estudo para o caso específico do problema a ser resolvido. Em paralelo, uma análise rigorosa deve ser feita na base de dados a fim de prepará-la para seu uso no modelo. Finalmente, com o modelo bem compreendido e instanciado e os dados devidamente preparados, a implementação do modelo pode ser feita.

# %% [markdown]
# ### Primeira etapa:

# %% [markdown]
# (1) **Notebook descrevendo detalhadamente o modelo:**
# * Um modelo é uma representação abstrata do mundo. No nosso caso, o "mundo" é o contexto onde o problema se insere. Desta forma, deve ser analisado com cuidado o que deve e o que não deve ser considerado. Por exemplo, se a base de dados tem 30 colunas, todas elas deverão ser utilizadas na implementação? Algumas poderão ser desconsideradas? Por quê?
# * Para utilizar a técnica em estudo, é preciso conhecê-la muito bem. Assim, nesta etapa, **deve ser feita uma descrição detalhada do problema e da técnica a ser utilizada.**
# * Deve ser elaborado um modelo com base na técnica em estudo.
# * O notebook, descrevendo o problema, a técnica em questão e o modelo elaborado deverá ser submetido na Plataforma Turing, até dia 31/1/2022.

# %% [markdown]
# ### Segunda etapa:

# %% [markdown]
# (2) **Notebook contendo a solução para o problema**. Poderão ser utilizados códigos desenvolvidos pelo grupo e/ou códigos de terceiros. No caso de se usar códigos desenvolvidos por terceiros, o(s) autor(es) desses códigos deve(m) ser devidamente referenciado(s) e os códigos devem ser devidamente documentados (comentários no próprio código e fora dele).
#
# (5) **Uma apresentação explicando detalhadamente como a técnica estudada foi utilizada para resolver o problema proposto** . Esta NÃO deve ser uma apresentação dos *notebooks* nem deve apresentar detalhes de codificação. Deve trazer uma descrição do problema, do modelo utilizado e da solução desenvolvida, de preferência utilizando slides ou algo parecido.
#
#
# Os produtos da segunda etapa deverão ser submetidos na Plataforma Turing até 31/01/2022.

# %% [markdown]
# **Observação:** Como não haverá Análise Exploratória de Dados a ser feita, o trabalho de implementação (segunda etapa) deverá ser dividido entre os dois membros do grupo. Entretanto, a primeira etapa e a avaliação dos resultados deve ser feita em grupo, isto é, um aluno deverá implementar os métodos de busca cega e o outro os métodos de busca informada. Cada aluno deverá entregar seu notebook com a implementação. A avaliação dos resultados das duas implementações deve ser apresentada em ambos os documentos entregue pelos alunos.
